# %% [markdown]
# #📌 Extracción

# %%
import pandas as pd

# %%
datos = pd.read_json("TelecomX_Data.json")

# %%
datos.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
datos
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# ...

# %%
datos["customer"].head()
# Out:
# 0    {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1    {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2    {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3    {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4    {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# Name: customer, dtype: object

# %% [markdown]
# #🔧 Transformación

# %%
import numpy as np

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %%
datos.dtypes
# Out:
# customerID    object
# Churn         object
# customer      object
# phone         object
# internet      object
# account       object
# dtype: object

# %%
customer=pd.json_normalize(datos["customer"])
customer.head()
phone=pd.json_normalize(datos["phone"])
phone.head()
internet=pd.json_normalize(datos["internet"])
internet.head()
account=pd.json_normalize(datos["account"])
account.head()
# Out:
#          Contract PaperlessBilling     PaymentMethod  Charges.Monthly  \
# 0        One year              Yes      Mailed check             65.6
# 1  Month-to-month               No      Mailed check             59.9
# 2  Month-to-month              Yes  Electronic check             73.9
# 3  Month-to-month              Yes  Electronic check             98.0
# 4  Month-to-month              Yes      Mailed check             83.9
#
#   Charges.Total
# 0         593.3
# 1         542.4
# 2        280.85
# 3       1237.85
# 4         267.4

# %%
datos_combinados = pd.concat([datos[['customerID', 'Churn']], customer, phone, internet, account], axis=1)

display(datos_combinados.head())
# Out:
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
# 1  0003-MKNFE    No    Male              0      No         No       9
# 2  0004-TLHLJ   Yes    Male              0      No         No       4
# 3  0011-IGKFF   Yes    Male              1     Yes         No      13
# 4  0013-EXCHZ   Yes  Female              1     Yes         No       3
#
#   PhoneService MultipleLines InternetService  ... OnlineBackup  \
# 0          Yes            No             DSL  ...          Yes
# 1          Yes           Yes             DSL  ...           No
# 2          Yes            No     Fiber optic  ...           No
# 3          Yes            No     Fiber optic  ...          Yes
# 4          Yes            No     Fiber optic  ...           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No         Yes         Yes              No        One year
# ...

# %%
datos_combinados.dtypes
# Out:
# customerID           object
# Churn                object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# Charges.Monthly     float64
# Charges.Total        object
# dtype: object

# %%
datos_combinados["Cuentas_Diarias"]=datos_combinados["Charges.Monthly"]/30
datos_combinados.head()
# Out:
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
# 1  0003-MKNFE    No    Male              0      No         No       9
# 2  0004-TLHLJ   Yes    Male              0      No         No       4
# 3  0011-IGKFF   Yes    Male              1     Yes         No      13
# 4  0013-EXCHZ   Yes  Female              1     Yes         No       3
#
#   PhoneService MultipleLines InternetService  ... DeviceProtection  \
# 0          Yes            No             DSL  ...               No
# 1          Yes           Yes             DSL  ...               No
# 2          Yes            No     Fiber optic  ...              Yes
# 3          Yes            No     Fiber optic  ...              Yes
# 4          Yes            No     Fiber optic  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %% [markdown]
# #📊 Carga y análisis

# %%
datos_combinados.describe()
# Out:
#        SeniorCitizen       tenure  Charges.Monthly  Cuentas_Diarias
# count    7267.000000  7267.000000      7267.000000      7267.000000
# mean        0.162653    32.346498        64.720098         2.157337
# std         0.369074    24.571773        30.129572         1.004319
# min         0.000000     0.000000        18.250000         0.608333
# 25%         0.000000     9.000000        35.425000         1.180833
# 50%         0.000000    29.000000        70.300000         2.343333
# 75%         0.000000    55.000000        89.875000         2.995833
# max         1.000000    72.000000       118.750000         3.958333

# %%
import matplotlib.pyplot as plt

churn_counts = datos_combinados['Churn'].value_counts()

plt.figure(figsize=(6, 6))
plt.pie(churn_counts, labels=churn_counts.index, autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightcoral'])
plt.title('Distribución de Churn')
plt.show()

# %%
categorical_cols = []
numerical_cols = []

for col in datos_combinados.columns:
    if col not in ['customerID', 'Churn']:
        if datos_combinados[col].dtype == 'object':
            categorical_cols.append(col)
        elif datos_combinados[col].dtype in ['int64', 'float64']:
            numerical_cols.append(col)

print("Categorical columns:", categorical_cols)
print("Numerical columns:", numerical_cols)
# Out:
# Categorical columns: ['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'Charges.Total']
# Numerical columns: ['SeniorCitizen', 'tenure', 'Charges.Monthly', 'Cuentas_Diarias']

# %%
import seaborn as sns

for col in categorical_cols:
    plt.figure(figsize=(10, 6))
    sns.countplot(data=datos_combinados, x=col, hue='Churn')
    plt.title(f'Distribution of {col} by Churn')
    plt.show()

for col in numerical_cols:
    plt.figure(figsize=(10, 6))
    sns.boxplot(data=datos_combinados, x='Churn', y=col)
    plt.title(f'Distribution of {col} by Churn')
    plt.show()

# %%
import seaborn as sns

for col in categorical_cols:
    plt.figure(figsize=(10, 6))
    sns.countplot(data=datos_combinados, x=col, hue='Churn')
    plt.title(f'Distribution of {col} by Churn')
    plt.show()

for col in numerical_cols:
    plt.figure(figsize=(10, 6))
    sns.boxplot(data=datos_combinados, x='Churn', y=col)
    plt.title(f'Distribution of {col} by Churn')
    plt.show()

# %% [markdown]
# #📄Informe final

# %% [markdown]
# ### 📊 Análisis de resultados
#
# Al analizar los datos, se observa que aproximadamente **el 75% de las personas decidió mantener su plan de suscripción**, lo que indica una tendencia positiva en la fidelización de usuarios.
#
# En general, **el género no es un factor decisivo** a la hora de continuar con el plan, ni tampoco influye de manera relevante el estado civil (casado o soltero).
#
# Por otro lado, se observa que:
# - Los clientes que **tienen dependientes cancelan en menor medida** su plan en comparación con quienes no los tienen.
# - Los clientes que cuentan con **servicio telefónico muestran una mayor tendencia a cancelar** su suscripción.
#
# Asimismo, se identifican patrones importantes en los servicios contratados:
# - Los usuarios con **fibra óptica presentan una mayor probabilidad de cancelar**.
# - Aquellos que **no poseen seguridad online ni respaldo online (backup)** también tienden a cancelar con más frecuencia.
# - Incluir servicios como **seguridad online, backup, películas y adicionales** puede **reducir la probabilidad de cancelación**, ya que incrementan la percepción de valor en el plan.
#
# Finalmente, en relación con los contratos y métodos de pago:
# - Los clientes con **contratos de un año o más muestran una tasa muy baja de cancelación**, mientras que quienes tienen **suscripción mensual presentan una tasa elevada**.
# - Casi el **50% de los clientes que utilizan chequeo electrónico para el pago se desuscriben**.
# - Los clientes que pagan **más de 2.5 USD diarios tienen una alta probabilidad de cancelar** su suscripción.
#
# 💡 **Recomendación:** Mantener las tarifas por debajo de este valor y promover métodos de pago alternativos puede contribuir a mejorar la retención de clientes.
